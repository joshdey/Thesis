# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d.axes3d import Axes3D
import ESNteachers as teach
from ESN import simple_ESN as sesn
import aux

# %%
trainin = teach.sine_teacher()
trainout = teach.sine_teacher(amp=1.0)

# %%
lor = sesn(N=3, K=1, L=1, binary_node=0)
W = lor.generate_W(rho=0.9, dens=0.5, cont=0)
Win=lor.generate_Win(dens=1.0)

# %%
train = lor.train_ESN(input_dat=trainin, teacher=trainout, around=0, order='relu', washout=50, mp=False, B=0.01)

# %%
runin = teach.sine_teacher(length=500)
runout = teach.sine_teacher(length=500, amp=1.0)

# %%
testrun = lor.run_ESN(input_dat=runin,around=0, order='relu',time=500)
out=lor.outputs

# %%
fig, ax = plt.subplots()
ax.plot(out)
ax.plot(runout)

# %%
aux.RMS(out, runout)
# Out:
# 0.029614865736823728
