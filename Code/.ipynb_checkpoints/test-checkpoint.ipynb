# %%
from ESN import simple_ESN as sesn
import ESN
import ESNteachers as teach

# %%
test = sesn(N=3, K=1, L=1, binary_node=0)

# %%
test.distribution()
# Out:
# 0.5307685357817962

# %%
W = test.generate_W(rho=0.9, dens=0.5, cont=0)
W
# Out:
# array([[ 0.        , -1.08988031,  0.        ],
#        [ 0.        ,  0.        ,  0.49941405],
#        [-0.96957984,  0.44776073,  0.        ]])

# %%
test.specify_W(W)
# Out:
# array([[ 0.        , -0.96878249,  0.        ],
#        [ 0.        ,  0.        ,  0.4439236 ],
#        [-0.86184875,  0.39800954,  0.        ]])

# %%
Win=test.generate_Win()
Win
# Out:
# array([[0.        ],
#        [0.74843156],
#        [0.        ]])

# %%
W_fb = test.generate_Wfb()
W_fb
# Out:
# array([[ 0.95892158],
#        [-0.41679728],
#        [ 0.84837182]])

# %%
sin_input = teach.sine_teacher()
sin_output = teach.sine_teacher(length=300, dt=0.01, f=8, amp=1)

# %%
train = test.train_ESN(input_dat=sin_input, teacher=sin_output, around=0, order=3, washout=50, mp=True)
train
# Out:
# array([[0.79422677, 0.08501535, 1.18527419]])

# %%
testrun = test.run_ESN(input_dat=sin_input,around=0, order=3,time=100)

# %%
test.plot_internal(nodes=[0,3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-5af6a3d82911> in <module>
# ----> 1 test.plot_internal(nodes=[0,3])
#
# ~/Documents/GitHub/Thesis/Code/ESN.py in plot_internal(self, nodes, rang, times, train, pltnum, pltsize)
#     410         plt.figure(num=pltnum,figsize=pltsize)
#     411         for i in nodes:
# --> 412             plt.plot(data[times[0]:times[1],i])
#     413
#     414
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
test.plot_eigvals()
