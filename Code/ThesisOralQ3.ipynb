# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d.axes3d import Axes3D
import ESNteachers as esnteach

# %%
x1, y1, z1 = esnteach.Lorenz(10000, 0.01, initvals=[1.0, 1.0, 1.0])

# %%
x2, y2, z2 = esnteach.Lorenz(10000, 0.01, initvals=[1.0, 1.0+10**-3, 1.0])

# %%
x3, y3, z3 = esnteach.Lorenz(10000, 0.01, initvals=[1.0, 1.0+10**-6, 1.0])

# %%
fig, axs = plt.subplots(3, sharex=True)
axs[0].plot(y1)
axs[1].plot(y2)
axs[2].plot(y3)

# %%
fig, ax = plt.subplots()
plt.plot(y1, label='1')
plt.plot(y2, label='1+10^-3')
plt.plot(y3, label='1+10^-6')
legend = ax.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.show()

# %%
deltay = y2-y1

# %%
plt.plot(deltay)
