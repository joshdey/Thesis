# %%
import aux
import matplotlib.pyplot as plt

# %%
out1, out2, rms, rmse1, rmse2, plot = aux.esn_wrapper(N=250, new_rho=1.0, in_sig=0.25,train_time=400, run_time=10000,teacher_system='Lorenz', directions=1, order=2)

# %%
rms
# Out:
# [370.7614483475445, 595.0443656839367]

# %%
plt.plot(rmse1, '.', markersize=1)
plt.show()

# %%
plt.plot(rmse2, '.', markersize=1)
plt.ylim(-10, 10)
# Out:
# (-10, 10)

# %%
plt.plot(out2)
plt.ylim(top=10, bottom=-10);

# %%
fig, axs = plt.subplots(3, 1, sharex=True)
fig.subplots_adjust(hspace=0)
axs[0].plot(rmse2, '.', markersize=1)
axs[0].set_ylim(-1, 10);
axs[1].plot(out2)
axs[1].set_ylim(-10,10);
