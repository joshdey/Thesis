# %%
import aux
import matplotlib.pyplot as plt

# %%
out1, out2, rms, rmse1, rmse2, plot = aux.esn_wrapper(N=250, new_rho=1.0, in_sig=0.25,train_time=1000, run_time=10000,teacher_system='Lorenz')

# %%
rms
# Out:
# [0.03471257321307196, 9.38289187569131]

# %%
plt.plot(rmse1, '.', markersize=1)
plt.show()

# %%
plt.plot(rmse2, '.', markersize=1)
plt.ylim(top=2.5, bottom=0);

# %%
plt.plot(out2)
plt.ylim(top=10, bottom=-10);

# %%
fig, axs = plt.subplots(3, 1, sharex=True)
fig.subplots_adjust(hspace=0)
axs[0].plot(rmse2, '.', markersize=1)
axs[0].set_ylim(-1, 10);
axs[1].plot(out2)
axs[1].set_ylim(-10,10);
