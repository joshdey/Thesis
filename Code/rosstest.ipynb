# %%
from ESN import simple_ESN as sesn
import ESN
import ESNteachers as teach
import numpy as np

# %%
ross = sesn(N=400, K=1, L=2, binary_node=0)
W = ross.generate_W(rho=0.9, dens=0.5, cont=0)
W = ross.specify_W(W)
W = ross.rescale_W()
Win=ross.generate_Win()
W_fb = ross.generate_Wfb()

# %%
x, y, z = teach.Rossler(10000, .01)

# %%
yz = np.concatenate((y,z), axis=1)

# %%
train = ross.train_ESN(input_dat=x, teacher=yz, around=0, order=2, washout=100, mp=False, B=0.01)

# %%
testrun, yz = ross.run_ESN(input_dat=x,around=0, order=2,time=10000)

# %%
intstates=ross.plot_internal(nodes=[0,99], times=[100, 30000])

# %%
#intnodes=ross.plot_nodes(times=[0, 3000000])

# %%
rossatrractor=ross.plot_attractor(name='testRossler')

# %%
ross.plot_eigvals(norm=True)
